# %% [markdown]
# <a href="https://colab.research.google.com/github/pqvinicius/logica-programacao-em-python-uninter/blob/aula_teorica/_LOGICA_DE_PROGRAMA%C3%87%C3%83O_EM_PYTHON_UNINTER_AT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# LOGICA DE PROGRAMAÇÃO EM PYTHON
# AULAS DE PYTHON DA UNINTER
# COLOCAREI AS AULAS TEORICAS AQUI

# %% [markdown]
# # AULA 2 - INTELIGÊNCIA ARTIFICIAL
